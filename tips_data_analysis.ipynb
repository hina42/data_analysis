# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Columns
#
# - total_bill: Total bill (dollars)
# - tip: Tip amount (dollars)
# - sex: Gender of the payer
# - smoker: Whether the payer smokes
# - day: Day of the week
# - time: Meal time (Lunch/Dinner)
# - size: Number of people in the part

# %% [markdown]
# ## Descriptive Statistics

# %%
print(tips.describe()) #summary of numerical a dataset
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print(tips.info()) #data types and null checks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
#Visualizing distribution of total_bill and tips

import matplotlib.pyplot as plt

sns.histplot(tips['total_bill'], kde=True)
plt.title('Distribution of total_bill')
plt.show()


sns.histplot(tips['tip'], kde=True)
plt.title('Distribution of tips')
plt.show()

# %%
#Analyzing categorical record count by sex, smoker, day and time

sns.countplot(data=tips, x='sex')
plt.title("Record Count by Gender")
plt.show()

sns.countplot(data=tips, x='smoker')
plt.title("Record Count by Smoker")
plt.show()

sns.countplot(data=tips, x='day')
plt.title("Record Count by Day")
plt.show()

sns.countplot(data=tips, x='time')
plt.title("Record Count by Time")
plt.show()

# %% [markdown]
# # Relationship Analysis

# %%
#Correlation between total_bill and tip

sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.title('Correlation between Total Bill and Tips')
plt.show()

# Correlation coefficient
print(tips[['total_bill', "tip"]].corr())
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
#Party size vs tip
sns.boxplot(data=tips, x="size", y="tip")
plt.title('Party Size vs Tip')
plt.show()

# Correlation coefficient
print(tips[['size', "tip"]].corr())
# Out:
#           size       tip
# size  1.000000  0.489299
# tip   0.489299  1.000000

# %%
#tips by gender
sns.boxplot(data=tips, x="sex", y="tip")
plt.title('Tips by Gender')
plt.show()

# %%
#tips by smoker
sns.boxplot(data=tips, x="smoker", y="tip")
plt.title('Tips by Smoker')
plt.show()

# %%
#tips by day
sns.boxplot(data=tips, x="day", y="tip")
plt.title('Tips by Day')
plt.show()

# %%
#tips distribution by percentage

tips['percentage'] = (tips['tip']/tips['total_bill'])*100

sns.histplot(data=tips['percentage'], kde=True)
plt.title('Distribution of tip by percentage')
plt.show()

# %%
#multivariable plot analyzing tips by day and gender

sns.catplot(data=tips, x='tip', y='day', hue='sex', kind='bar')
plt.title('Tips by day and Gender')
plt.show()

sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex')
# Out:
# C:\Users\wajiz.pk\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\wajiz.pk\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\wajiz.pk\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
gender_tip = tips.groupby('sex')['tip'].mean()
day_total_bill = tips.groupby('day')['total_bill'].mean()
smoker_tip = tips.groupby('smoker')['tip'].mean()
party_tip = tips.groupby('size')['tip'].mean()

print(tips.describe())
print(tips['sex'].value_counts(), tips['smoker'].value_counts(), tips['time'].value_counts(), tips['day'].value_counts())

# Correlation
print(tips[['total_bill', "tip"]].corr())
print(tips[['size', "tip"]].corr())
# Out:
#        total_bill         tip        size  percentage
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672   16.080258
# std      8.902412    1.383638    0.951100    6.107220
# min      3.070000    1.000000    1.000000    3.563814
# 25%     13.347500    2.000000    2.000000   12.912736
# 50%     17.795000    2.900000    2.000000   15.476977
# 75%     24.127500    3.562500    3.000000   19.147549
# max     50.810000   10.000000    6.000000   71.034483
# sex
# Male      157
# Female     87
# Name: count, dtype: int64 smoker
# No     151
# Yes     93
# Name: count, dtype: int64 time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64 day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000
#           size       tip
# size  1.000000  0.489299
# tip   0.489299  1.000000

# %% [markdown]
# ## Key Metrics
#
# Numerical
# - Average Total Bill = 19.78
# - Average Tip = 2.99
# - Average Party Size = 2.5
# - Average tip percentage = 16%
# - Total bill values range between 3 and 50 with most bills around 17 and 24
# - Total tip values range between 1 and 10 with most tips around 2.9 and 3.5
#
# Categorical
# - Gender: Equal distribution, with slightly more males (64%).
# - Smoker: Slightly more non smokers (61%) then smokers.
# - Time: More tips were given during dinner time (72%).
# - Day: Most tips were given on weekends and least tips were given on Fridays.
#
# Correlations
# - A positive correlation between the total bill and tip indicates higher bills incourage more tips
# - A party of larger size generates more tips
#
# ## Key Insights
#
#
# 1. Gender and Tipping Behavior
#
# Male customers tip slightly more (3.09) than female customers (2.83), despite similar average total bills.
# Males also have a higher tip percentage (16.66%) compared to females (14.83%).
#
# 2. Smoking vs Non-Smoking
#
# Smokers tip slightly less on average (2.93) than non-smokers (3.02).
# Non-smokers account for the majority of customers (62%).
# Average tip percentage is higher among non-smokers (16.04%) than smokers (14.91%).
#
# 3. Time of Day
#
# Dinner: Generates higher total bills (20.79) and tips (3.00) compared to lunch (17.08, 2.71).
# Dinner also attracts larger groups (average party size: 2.7 vs. 2.4 for lunch).
#
# 4. Day-Wise Trends
#
# Sunday: Highest average total bills (21.41) and tips (3.40). Ideal for promotions or campaigns.
# Friday: Lowest average total bills (17.15) and tips (2.73).
# Thursday: Attracts smaller parties (2.45) and generates lower average tips (2.77).
#
# 5. Party Size
#
# Larger parties (size 5-6) tend to leave higher total tips but lower tip percentages.
# Smaller groups (size 1-2) leave higher tip percentages (17) compared to larger groups (12%-15%).
#
# Correlations
#
# - Total Bill and Tip: Strong positive correlation (0.67), meaning higher total bills result in higher tips.
# - Tip Percentage and Total Bill: Negative correlation (-0.14), suggesting customers tip a smaller percentage as the bill increases.
# - Party Size and Total Bill: Moderate correlation (0.59), indicating larger groups tend to spend more.
#
# Recommendations
#
# - Sunday has the highest revenue potential. Focus on family-sized meals and group discounts.
#
# - Non-smokers tip higher as a percentage. Incentivizing non-smoking sections could boost tips.
#
# - Dinner attracts larger groups and higher spending. Target advertisements for premium meal bundles during dinner.
#
# - Staff can encourage better tipping through excellent service, especially for smaller groups and during lunch.
#
# - Large parties spend more but tip less as a percentage. Introduce gratuity policies for groups larger than 5.
